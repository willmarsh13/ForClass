# %% [markdown]
# <a href="https://colab.research.google.com/github/willmarsh13/ForClass/blob/master/PetShop.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![Pet Shop.png](data:image/png;base64,...)

# %% [markdown]
# I presented my ER Diagram as such because I thought it represented the many different connections (not all) that each entity relates to each other with. I thought it was very interesting thinking through the cardinality of each entity and how they relate to other entities and attributes. I thought all but the "transaction" entities were pretty straight forward. The "transaction" entity I had some fun with, thinking about how the cardinality of it would be affected by different attributes. For example, I thought about connecting price to food, but then I thought about the cardinality of price, and figured it would be best to connect through customer instead of a direct relationship between food and transaction. Ultimately, it took a lot of thought, but it was interesting to think through.
