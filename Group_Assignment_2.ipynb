# %% [markdown]
# <a href="https://colab.research.google.com/github/willmarsh13/ForClass/blob/master/Group_Assignment_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# For our project we decided to create a database for Penn State Athletics so recruits, coaches, players, and administration can have easy access to all Penn State Athletics data.  This model that we have presented gives viewers an inside look at how all these entities contribute to how we are able to see, and watch our favorite Penn State Athletics teams and the relationships each of these entities have with another.  We started off with the Facility, which would determine how many people it could house.  Once we look at the facility then we have to look at how the public would come in contact with the games which would be through our ticket sales depending on the capacity of each facility.  This would give each person their own specific ID which would only allow them to scan in once.  As we look into ticket sales, each sport will have a specific number of tickets sold due to capacity limits in each facility.  Lastly we looked at what season these games would be played in because that also makes the sport unique, and the coaches as well, because each sport has its own coach.  We chose these entities as they are the main attributes that distinguish one sport from another.  This database would help make it easier for Penn State Athletics to stay organized throughout the year and develop an easier way to recall data from previous years.

# %% [markdown]
# ![Group Assignment 2.png](data:image/png;base64,...)
