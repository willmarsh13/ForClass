# %% [markdown]
# <a href="https://colab.research.google.com/github/willmarsh13/PracticeForClass/blob/master/Lab1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Do you like using Jupyter Notebooks?
# I am not sure how I feel about it yet, it seems like a blend of a lot of stuff I've used in the past, so we will see, with time, how I feel. I always learn best by doing so the more labs we have using it, the more I will get used to it.

# %% [markdown]
# # What do you want to learn more about in Jupyter Notebooks?
# I want to learn more about how to make the information flow on a page instead of just creating obvious breaks in the page. I think that is critical to maintaining interest when displaying data on a site. We want to engage the audience and the best way to do so is with data explained in a satisfying way.

# %% [markdown]
# ![HLP_0584xcolor5x7_WEB_RES.jpg](data:image/jpeg;base64,...)
